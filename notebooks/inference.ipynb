# %%
# Theory
"""
- Training
- Inference
    - Runtime
    - Infra
    - Tooling


Techniques - Batching, caching, quantization, speculation, parallelism, disaggregation
Inference library
vLLM, SGLang, TensorRT-LLM
pytorch, cuda

shared vs onpremis/dedicated
latency vs throughput
availability vs reliability

Model selection, Model evaluation
"""

# %%
import torch
B, T = 2, 4
torch.manual_seed(42)
x = torch.randint(0, 100, (B, T))
print(x.shape)
print(x)
# Out:
# torch.Size([2, 4])
# tensor([[42, 67, 76, 14],
#         [26, 35, 20, 24]])
